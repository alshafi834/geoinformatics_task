# %% [markdown]
# # Final assignment
#
# scrapping website master data

# %% [markdown]
# ### At first check the conda environment

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /Users/aalshafi/opt/anaconda3
# geo2                     /Users/aalshafi/opt/anaconda3/envs/geo2
# geo3                     /Users/aalshafi/opt/anaconda3/envs/geo3
# geo_water             *  /Users/aalshafi/opt/anaconda3/envs/geo_water
# geotemp                  /Users/aalshafi/opt/anaconda3/envs/geotemp
# test_environment         /Users/aalshafi/opt/anaconda3/envs/test_environment

# %% [markdown]
# ### Import all the necessary packages

# %%
import requests
from bs4 import BeautifulSoup
from shapely.geometry import Polygon
import geopandas as gpd
import pandas as pd
import os
import csv
import psycopg2

# %% [markdown]
# ### Scrape the master data from web URL
#
# Here we are looping over the URL with PIDVal and scrapping the master data. Then the scrapped data is stored in a csv file as well as into the Postgres database.

# %%
# %load_ext sql
# %sql postgresql://env_master:M123xyz@localhost/groundwater

base_url = r"https://howis.eglv.de/pegel/html/stammdaten_html/MO_StammdatenPegel.php?PIDVal="


with open('output.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Define the column headers
    column_headers = ['urlparamid', 'pegelnummer', 'gewasser', 'flusskilometer', 'pegelnullpunkt', 'einzugsgebiet', 'rechtswert', 'hochwert', 'mhw', 'mw', 'mnw']
    
    # Write the column headers to the CSV file
    writer.writerow(column_headers)
    
    for i in range(1, 93):
        url = base_url + str(i)
        
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        td_tags = soup.find_all('td')
        td_texts = [td.text.strip() for td in td_tags]
        td_texts.insert(0, i)
        selected_td_texts = [td_texts[i] for i in [0, 3, 5, 7, 9, 11, 13, 15, 18, 21, 24]]
        selected_td_texts = [val if val not in ("", "-") else None for val in selected_td_texts]
        
        var1 = selected_td_texts[0]
        var2 = selected_td_texts[1]
        var3 = selected_td_texts[2]
        var4 = selected_td_texts[3]
        var5 = selected_td_texts[4]
        var6 = selected_td_texts[5]
        var7 = selected_td_texts[6]
        var8 = selected_td_texts[7]
        var9 = selected_td_texts[8]
        var10 = selected_td_texts[9]
        var11 = selected_td_texts[10]
        
        if selected_td_texts[1] is not None:
            print(selected_td_texts)
            # cur.execute("INSERT INTO Masterdata (urlparamid, pegelnummer, gewasser, flusskilometer, pegelnullpunkt, einzugsgebiet, rechtswert, hochwert, mhw, mw, mnw) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", selected_td_texts)
            #%sql INSERT INTO "Masterdata" (urlparamid, pegelnummer, gewasser, flusskilometer, pegelnullpunkt, einzugsgebiet, rechtswert, hochwert, mhw, mw, mnw) VALUES (:var1, :var2, :var3, :var4, :var5, :var6, :var7, :var8, :var9, :var10, :var11)
            writer.writerow(selected_td_texts)
# Out:
# [2, '10104', 'Berne', '1.40', '31.48', None, '2566184.00', '5707172.00', None, None, None]
# [3, '10105', 'Berne', '2.83', '32.91', None, '2567323.00', '5706410.00', None, None, None]
# [4, '10106', 'Borbecker Mb.', '0.65', '34.22', None, '2567540.00', '5705975.00', None, None, None]
# [5, '11038', 'Borbecker Mb.', '1.79', '37.10', None, '2567629.83', '5704851.75', '244', '47', '37']
# [6, '12036', 'Borbecker Mb.', '2.20', '37.18', None, '2567554.00', '5704546.00', None, None, None]
# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import sqlalchemy

df = pd.read_csv("output.csv")
#print(df)


gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.rechtswert, df.hochwert), crs="EPSG:31466")
print(gdf)

engine = sqlalchemy.create_engine("postgresql://env_master:M123xyz@localhost/groundwater")
conn = engine.connect()

gdf.to_postgis('Masterdata', con=conn, if_exists='append', index=False)
# Out:
#     urlparamid  pegelnummer           gewasser  flusskilometer  \
# 0            2        10104              Berne            1.40
# 1            3        10105              Berne            2.83
# 2            4        10106      Borbecker Mb.            0.65
# 3            5        11038      Borbecker Mb.            1.79
# 4            6        12036      Borbecker Mb.            2.20
# ..         ...          ...                ...             ...
# 62          86        22105      Pelkumer Bach            0.00
# 63          88        10071       Landwehrbach            3.10
# 64          89        10101            Emscher           16.30
# 65          91        20046  Sickingmühlenbach            1.70
# 66          92        10097            Ostbach            4.49
#
#     pegelnullpunkt  einzugsgebiet  rechtswert    hochwert    mhw     mw  \
# 0            31.48            NaN  2566184.00  5707172.00    NaN    NaN
# 1            32.91            NaN  2567323.00  5706410.00    NaN    NaN
# 2            34.22            NaN  2567540.00  5705975.00    NaN    NaN
# 3            37.10            NaN  2567629.83  5704851.75  244.0   47.0
# 4            37.18            NaN  2567554.00  5704546.00    NaN    NaN
# ..             ...            ...         ...         ...    ...    ...
# 62           49.06            NaN  2618591.86  5724496.35    NaN    NaN
# 63           46.20            NaN  2595761.32  5708883.15    NaN    NaN
# 64           27.09            NaN  2565049.27  5708062.06  515.0  172.0
# 65           28.93            NaN  2571367.27  5722139.21    NaN    NaN
# 66           64.85            NaN  2586492.48  5712124.00    NaN    NaN
#
#       mnw                         geometry
# 0     NaN  POINT (2566184.000 5707172.000)
# 1     NaN  POINT (2567323.000 5706410.000)
# 2     NaN  POINT (2567540.000 5705975.000)
# 3    37.0  POINT (2567629.830 5704851.750)
# 4     NaN  POINT (2567554.000 5704546.000)
# ..    ...                              ...
# 62    NaN  POINT (2618591.860 5724496.350)
# 63    NaN  POINT (2595761.320 5708883.150)
# 64  136.0  POINT (2565049.270 5708062.060)
# 65    NaN  POINT (2571367.270 5722139.210)
# 66    NaN  POINT (2586492.480 5712124.000)
#
# [67 rows x 12 columns]

# %% [markdown]
# ### Connect to the database with SQLAlchemy and SQL magic
#
# Here we are connecting with the database and showing all the inserted rows that we scrapped from the website.

# %%
engine = sqlalchemy.create_engine("postgresql://env_master:M123xyz@localhost/groundwater")
engine
# Out:
# Engine(postgresql://env_master:***@localhost/groundwater)

# %%
engine.connect()

# %%
# %load_ext sql

# %%
# %sql postgresql://env_master:M123xyz@localhost/groundwater
# %sql select * from "Masterdata"
# Out:
#  * postgresql://env_master:***@localhost/groundwater
# 67 rows affected.
# [(Decimal('2.00'), Decimal('10104.00'), 'Berne', Decimal('1.40'), Decimal('31.48'), None, Decimal('2566184.00'), Decimal('5707172.00'), None, None, None, '0101000020EA7A000000000000149443410000000069C55541'),
#  (Decimal('82.00'), Decimal('20106.00'), 'Pelkumer Bach', Decimal('0.73'), Decimal('52.63'), None, Decimal('2619046.66'), Decimal('5724690.38'), None, None, None, '0101000020EA7A000048E17A5453FB434185EB519884D65541'),
#  (Decimal('83.00'), Decimal('23083.00'), 'Herringer Bach', Decimal('3.45'), Decimal('53.15'), None, Decimal('2622459.88'), Decimal('5725894.67'), None, None, None, '0101000020EA7A00000AD7A3F0FD014441AE47E1AAB1D75541'),
#  (Decimal('84.00'), Decimal('24083.00'), 'Herringer Bach', Decimal('3.33'), Decimal('53.20'), None, Decimal('2622346.88'), Decimal('5725949.07'), None, None, None, '0101000020EA7A00000AD7A370C501444148E17A44BFD75541'),
#  (Decimal('86.00'), Decimal('22105.00'), 'Pelkumer Bach', Decimal('0.00'), Decimal('49.06'), None, Decimal('2618591.86'), Decimal('5724496.35'), None, None, None, '0101000020EA7A0000E17A14EE6FFA43416666661654D65541'),
#  (Decimal('88.00'), Decimal('10071.00'), 'Landwehrbach', Decimal('3.10'), Decimal('46.20'), None, Decimal('2595761.32'), Decimal('5708883.15'), None, None, None, '0101000020EA7A00008FC2F5A8D8CD43419A9999C914C75541'),
#  (Decimal('89.00'), Decimal('10101.00'), 'Emscher', Decimal('16.30'), Decimal('27.09'), None, Decimal('2565049.27'), Decimal('5708062.06'), Decimal('515.00'), Decimal('172.00'), Decimal('136.00'), '0101000020EA7A0000295C8FA2DC9143413D0AD78347C65541'),
#  (Decimal('91.00'), Decimal('20046.00'), 'Sickingmühlenbach', Decimal('1.70'), Decimal('28.93'), None, Decimal('2571367.27'), Decimal('5722139.21'), None, None, None, '0101000020EA7A0000295C8FA2339E4341D7A370CD06D45541'),
#  (Decimal('92.00'), Decimal('10097.00'), 'Ostbach', Decimal('4.49'), Decimal('64.85'), None, Decimal('2586492.48'), Decimal('5712124.00'), None, None, None, '0101000020EA7A0000D7A3703DBEBB4341000000003FCA5541')]

# %% [markdown]
# ### Periodic data scrapping
#
# Here we are scrapping all the water level data along with other information from the website periodically and storing it into a csv file. The script is run every 15 minutes by a cronjob that was set up in the machine. The cron job is being managed by crontab.

# %%
import os
import csv
import requests
from bs4 import BeautifulSoup
from datetime import datetime

url = 'https://howis.eglv.de/pegel/html/uebersicht_internet.php'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

tooltip_divs = soup.select('div.tooltip')
tooltip_heads = []
id_counter = 1

# for div in tooltip_divs:
#     tooltip_head = div.select_one('.tooltip-head').text.replace('\n', '')
#     tooltip_head_data = ['s'+str(id_counter), tooltip_head, datetime.now().strftime('%Y-%m-%d %H:%M:%S')]
#     tooltip_values = div.select('td.tooltip-value')
#     for value in tooltip_values:
#         tooltip_head_data.append(value.text.replace('\xa0', ''))
#     tooltip_heads.append(tooltip_head_data)
#     id_counter += 1

for div in tooltip_divs:
    tooltip_head = div.select_one('.tooltip-head').text.replace('\n', '')
    tooltip_head_data = ['s'+str(id_counter), tooltip_head, datetime.now().strftime('%Y-%m-%d %H:%M:%S')]
    tooltip_values = div.select('td.tooltip-value')
    for i, value in enumerate(tooltip_values):
        if i == 0:
            tooltip_head_data.append('w')
            trimmedValue = value.text.replace('\xa0', '')
            if trimmedValue.isdigit():
                tooltip_head_data.append(trimmedValue)
                tooltip_heads.append(tooltip_head_data)
    id_counter += 1
 
id_counter = 1
for div in tooltip_divs:
    tooltip_head = div.select_one('.tooltip-head').text.replace('\n', '')
    tooltip_head_data = ['s'+str(id_counter), tooltip_head, datetime.now().strftime('%Y-%m-%d %H:%M:%S')]
    tooltip_values = div.select('td.tooltip-value')
    for i, value in enumerate(tooltip_values):
        if i == 1:
            tooltip_head_data.append('q')
            trimmedValue = value.text.replace('\xa0', '')
            if len(trimmedValue) > 2:
                tooltip_head_data.append(trimmedValue)
                tooltip_heads.append(tooltip_head_data)
    id_counter += 1

filename = '/Users/aalshafi/GeoInformatics/finalassignment/periodic_data.csv'
file_exists = os.path.isfile(filename)

# Write the data to a CSV file
with open(filename, 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    if not file_exists:  # Check if the file exists and if not, write the header row
        writer.writerow(['sid', 'place', 'timestamp', 'param', 'value'])
    for item in tooltip_heads:
        writer.writerow(item)

# %% [markdown]
# ### Checking timestamp

# %%
import time

import datetime

current_timestamp = time.time()
current_datetime = datetime.datetime.fromtimestamp(current_timestamp)
print(current_datetime)
# Out:
# 2023-03-19 13:16:52.941019

# %% [markdown]
# ### Inserting periodic data and cleaning up the csv file
#
# Here we are inserting all the rows from the csv file to Postgres database and cleaning up the rows from csv file after inserting it into the database. This script is also run by a cron job every 20 minutes.

# %%
#%load_ext sql

#%sql postgresql://env_master:M123xyz@localhost/groundwater

import pandas as pd
import psycopg2
import sqlalchemy
import os

engine = sqlalchemy.create_engine("postgresql://env_master:M123xyz@localhost/groundwater")
conn = engine.connect()
#conn = psycopg2.connect(host="localhost", database="groundwater", user="env_master", password="M123xyz")

df = pd.read_csv('periodic_data.csv')

df.to_sql('Waterlevel', con=conn, if_exists='append', index=False)

# delete all rows except the header from the CSV file
#os.remove('periodic_data.csv')
# Out:
# 296

# %% [markdown]
# ### Showing all the timeseries data inserted into the database

# %%
# %sql postgresql://env_master:M123xyz@localhost/groundwater
# %sql select * from "Waterlevel"
# Out:
#  * postgresql://env_master:***@localhost/groundwater
# 9296 rows affected.
# [('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('341.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('620.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('344.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('156.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('142.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('182.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('103.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('259.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'w', Decimal('106.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'q', Decimal('94.50')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 10, 2), 'q', Decimal('51.50')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('341.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('620.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('344.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('156.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('142.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('182.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('103.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('258.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'w', Decimal('106.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'q', Decimal('94.50')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'q', Decimal('51.90')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 15, 1), 'q', Decimal('14.90')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('620.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('155.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('142.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('182.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('103.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('259.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'w', Decimal('106.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'q', Decimal('93.40')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 20, 1), 'q', Decimal('51.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('620.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('155.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('142.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('182.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('103.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('258.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'w', Decimal('106.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'q', Decimal('93.40')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'q', Decimal('51.60')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 25, 1), 'q', Decimal('14.70')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('620.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('155.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('182.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('102.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('258.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'w', Decimal('105.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'q', Decimal('93.40')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'q', Decimal('51.10')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 1, 30, 2), 'q', Decimal('14.80')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('341.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('155.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('142.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('181.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('101.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('257.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'w', Decimal('105.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'q', Decimal('93.90')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'q', Decimal('51.80')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 0, 2), 'q', Decimal('14.70')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('142.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('181.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('101.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('257.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'w', Decimal('105.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'q', Decimal('94.30')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'q', Decimal('51.40')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 5, 2), 'q', Decimal('14.60')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('142.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('181.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('101.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('257.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'w', Decimal('105.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'q', Decimal('94.30')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'q', Decimal('51.30')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 10, 1), 'q', Decimal('14.80')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('348.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('181.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('101.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'w', Decimal('104.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'q', Decimal('94.30')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'q', Decimal('51.10')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 15, 1), 'q', Decimal('14.60')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('181.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('101.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'w', Decimal('104.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'q', Decimal('94.10')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'q', Decimal('51.50')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 20, 1), 'q', Decimal('14.50')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('326.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('100.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'w', Decimal('104.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'q', Decimal('94.10')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'q', Decimal('51.30')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 25, 1), 'q', Decimal('14.80')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('100.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'w', Decimal('104.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'q', Decimal('94.10')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'q', Decimal('51.80')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 30, 1), 'q', Decimal('14.60')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('100.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'w', Decimal('104.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'q', Decimal('50.90')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 35, 2), 'q', Decimal('14.60')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('100.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'w', Decimal('104.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'q', Decimal('51.30')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 40, 2), 'q', Decimal('14.80')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('340.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('99.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'w', Decimal('104.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'q', Decimal('51.40')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 45, 1), 'q', Decimal('14.50')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('99.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('256.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'q', Decimal('51.30')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 50, 2), 'q', Decimal('14.90')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('141.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('99.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'q', Decimal('51.70')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 2, 55, 2), 'q', Decimal('14.60')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('154.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('140.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('180.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('99.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'q', Decimal('51.80')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 0, 2), 'q', Decimal('14.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('140.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('99.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'q', Decimal('94.70')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 5, 2), 'q', Decimal('14.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('140.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('99.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'q', Decimal('94.70')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 10, 2), 'q', Decimal('14.70')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('98.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'q', Decimal('94.70')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'q', Decimal('52.10')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 15, 2), 'q', Decimal('14.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('98.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'q', Decimal('94.30')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'q', Decimal('51.50')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 20, 2), 'q', Decimal('14.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('98.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'q', Decimal('94.30')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'q', Decimal('50.40')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 25, 1), 'q', Decimal('14.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('621.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('98.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'w', Decimal('103.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'q', Decimal('94.30')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'q', Decimal('48.40')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 30, 2), 'q', Decimal('14.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('98.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'w', Decimal('102.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'q', Decimal('95.10')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'q', Decimal('48.50')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 35, 2), 'q', Decimal('14.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('179.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('97.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('255.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'w', Decimal('102.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'q', Decimal('95.10')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 40, 2), 'q', Decimal('14.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('339.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('178.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('97.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'w', Decimal('102.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'q', Decimal('95.10')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'q', Decimal('49.10')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 45, 1), 'q', Decimal('14.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('178.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('97.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'w', Decimal('102.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'q', Decimal('49.60')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 50, 2), 'q', Decimal('14.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('139.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('178.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('97.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'w', Decimal('102.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'q', Decimal('50.70')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 3, 55, 1), 'q', Decimal('14.20')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('153.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('138.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('178.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('97.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'w', Decimal('102.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'q', Decimal('51.30')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 0, 2), 'q', Decimal('14.60')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('324.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('152.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('138.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('177.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('97.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'w', Decimal('102.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'q', Decimal('51.80')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 5, 2), 'q', Decimal('14.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('325.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('152.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('138.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('177.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('97.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'w', Decimal('102.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'q', Decimal('51.80')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 10, 1), 'q', Decimal('14.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('342.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('324.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('152.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('138.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('177.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('96.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'w', Decimal('101.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'q', Decimal('51.80')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 15, 2), 'q', Decimal('14.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('324.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('152.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('138.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('177.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('96.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'w', Decimal('101.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'q', Decimal('51.50')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 20, 2), 'q', Decimal('14.20')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('324.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('152.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('138.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('177.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('96.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('254.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'w', Decimal('101.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'q', Decimal('94.20')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'q', Decimal('51.60')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 4, 25, 2), 'q', Decimal('14.10')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('343.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('622.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('324.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('338.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('152.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('137.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 4, 30, 2), 'w', Decimal('177.00')),
# ...
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'w', Decimal('350.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'w', Decimal('150.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'w', Decimal('133.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'w', Decimal('171.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'w', Decimal('247.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'w', Decimal('100.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'q', Decimal('51.70')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 6, 45, 2), 'q', Decimal('13.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('341.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('150.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('133.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('171.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('247.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'w', Decimal('100.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'q', Decimal('94.50')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'q', Decimal('52.40')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 6, 50, 2), 'q', Decimal('13.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('341.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('150.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('133.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('171.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('247.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'w', Decimal('100.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'q', Decimal('94.50')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'q', Decimal('52.10')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 6, 55, 2), 'q', Decimal('13.20')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('341.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('150.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('133.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('171.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('247.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'q', Decimal('94.50')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'q', Decimal('51.80')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 0, 2), 'q', Decimal('13.20')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('341.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('150.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('133.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('170.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('247.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'q', Decimal('94.90')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 5, 2), 'q', Decimal('52.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('341.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('150.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('133.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('170.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('247.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'q', Decimal('94.90')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'q', Decimal('52.30')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 10, 1), 'q', Decimal('13.20')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('341.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('150.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('132.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('170.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('246.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'q', Decimal('94.90')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 15, 2), 'q', Decimal('13.20')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('149.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('132.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('169.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('246.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'q', Decimal('95.40')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'q', Decimal('52.10')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 20, 2), 'q', Decimal('13.10')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('323.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('149.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('132.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('169.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('246.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 25, 2), 'q', Decimal('95.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('322.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('149.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('132.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('169.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('246.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'q', Decimal('95.40')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 30, 2), 'q', Decimal('51.20')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('322.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('149.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('132.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('169.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('245.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 35, 2), 'q', Decimal('94.30')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('322.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('149.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('132.00')),
#  ('s8', '10101 Bottrop, Essener Straße ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('169.00')),
#  ('s9', '10119 Gelsenkirchen, Adenauerallee ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('92.00')),
#  ('s11', '10103 Bahnstraße ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('246.00')),
#  ('s12', '10124 Recklinghausen, Am Stadthafen ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'w', Decimal('99.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'q', Decimal('94.30')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 40, 2), 'q', Decimal('50.40')),
#  ('s1', '20001 Fusternberg ', datetime.datetime(2023, 3, 28, 7, 45, 2), 'w', Decimal('344.00')),
#  ('s2', '20004 Dorsten ', datetime.datetime(2023, 3, 28, 7, 45, 2), 'w', Decimal('623.00')),
#  ('s3', '28085 Haltern ', datetime.datetime(2023, 3, 28, 7, 45, 2), 'w', Decimal('322.00')),
#  ('s4', '20008 Lünen ', datetime.datetime(2023, 3, 28, 7, 45, 2), 'w', Decimal('342.00')),
#  ('s5', '20012 KA Hamm ', datetime.datetime(2023, 3, 28, 7, 45, 2), 'w', Decimal('349.00')),
#  ('s6', '10026 Mengede, A45 ', datetime.datetime(2023, 3, 28, 7, 45, 2), 'w', Decimal('149.00')),
#  ('s7', '10008 Bottrop-Süd ', datetime.datetime(2023, 3, 28, 7, 45, 2), 'w', Decimal('131.00')),
#  ...]
